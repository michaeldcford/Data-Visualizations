# %% [markdown]
# <a href="https://colab.research.google.com/github/michaeldcford/Data-Visualizations/blob/main/Data_Visualization_Portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step one: importing necessary libraries

# %%
import numpy as np #numpy provides fast mathematical function processing
import pandas as pd #pandas is used for easy indexing and data collection tools
import matplotlib as mpl #high level data vizualization library
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Step two: importing data from github

# %%
#Read csv from github url
CountyVote=pd.read_csv("https://raw.githubusercontent.com/michaeldcford/Data-Visualizations/main/governors_county.csv",encoding='latin1')

# %% [markdown]
# Step three: review data

# %%
#This function previews your data
CountyVote.head()

# %%
#Give a list of column names
CountyVote.columns.values
# Out:
# array(['state', 'county', 'current_votes', 'total_votes', 'percent'],
#       dtype=object)

# %%
#Give size of data uploaded
CountyVote.shape
# Out:
# (1025, 5)

# %%
#Present all of data
CountyVote

# %%
CountyVote.plot

# %%
#Rename Dataframe to not overwrite original
#Execute Code
#Pick two columns

CountyVote2=CountyVote.plot.line(x='county', y='percent')

plt.title('Line Plot')
plt.xlabel('county')
plt.ylabel('percent')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
CountyVote3=CountyVote.plot.barh(x='county', y='total_votes')

plt.title('Bar Plot')
plt.xlabel('county')
plt.ylabel('total votes')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
CountyVote4=CountyVote.plot.scatter(x='current_votes', y='total_votes')

plt.title('Scatter Plot')
plt.xlabel('current')
plt.ylabel('total')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
CountyVote3=CountyVote.plot.barh(x='county', y='total_votes')

plt.title('Bar Plot')
plt.xlabel('county')
plt.ylabel('total votes')
plt.rcParams['figure.figsize']={15,20}
plt.show
# Out:
# <function matplotlib.pyplot.show>
